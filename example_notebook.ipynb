# %%
import lseg.data as ld
import plotly.express as px
import plotly

# %%
print(f'Data Library version {ld.__version__}')
# Out:
# Data Library version 2.1.1

# %%
print(f'Plotly version {plotly.__version__}')
# Out:
# Plotly version 6.5.2
